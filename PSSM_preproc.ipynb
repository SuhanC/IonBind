# %%
from preproc_utils import *
from sequence_postproc_utils import *
import pandas as pd
import numpy as np
import random

# %%
from Get_PSSM import *

# %%
pssm_path = '/Users/suhancho/data/Uniprot_metalbinding_challenge/PSSM/'
pssm_files = [pssm_path+f for f in os.listdir(pssm_path)]

# %%
get_processed_pssm(pssm_files[1])
# Out:
#           A   R       N   D   C       Q   E   G   H   I  ... Func_polar  \
# Residue                                                  ...
# M        -4  -5      -6  -6  -5      -4  -5  -6  -5   0  ...          0
# S         2   1      -1  -1  -3      -1  -1   0  -3  -4  ...          1
# R        -1   4       0  -3  -4       0  -1  -3   2   1  ...          0
# L        -4  -2      -6  -6  -5      -3  -6  -7  -5   5  ...          0
# F        -9  -5  -6 -10  -4  -4  -9 -10  -8  -3  -4  -7  ...          0
# ...      ..  ..     ...  ..  ..     ...  ..  ..  ..  ..  ...        ...
# E        -2   2      -2   0  -5       2   4  -3   1  -2  ...          0
# A         3  -1       0   0  -2       0   1   1  -2  -2  ...          0
# K         0   2      -2  -2  -4       1   2  -3   1  -1  ...          0
# C         0  -4      -4  -2   8      -3  -4  -1  -4   2  ...          1
# N        -2  -1       7   0  -4      -1  -1  -2  -1  -4  ...          1
#
#         Func_alipathic Func_aromatic Func_negative Func_positive Volume_tiny  \
# Residue
# M                    1             0             0             0           0
# S                    0             0             0             0           1
# R                    0             0             0             1           0
# L                    1             0             0             0           0
# F                    0             1             0             0           0
# ...                ...           ...           ...           ...         ...
# E                    0             0             1             0           0
# A                    1             0             0             0           1
# K                    0             0             0             1           0
# C                    0             0             0             0           1
# N                    0             0             0             0           0
#
#         Volume_small Volume_big HBdonor HBacceptor
# Residue
# M                  0          1    1.02       1.12
# S                  0          0    2.31       2.04
# R                  0          1    5.40       1.20
# L                  0          1    0.98       1.20
# F                  0          1    0.92       1.08
# ...              ...        ...     ...        ...
# E                  0          1    0.93       4.43
# A                  0          0    0.95       1.16
# K                  0          1    3.59       1.12
# C                  0          0    0.96       1.12
# N                  1          0    2.24       2.41
#
# [448 rows x 32 columns]

# %%
def get_processed_pssm(pssm_file):
    test_pssm = get_PSSM_mat(pssm_files[1])
    test_seq = ''.join(test_pssm.index.tolist())
    test_pssm['Charge']=get_charge(test_seq)
    test_pssm['Hydro']=get_hydro(test_seq)

    test_pssm['Func_polar']=get_func_group(test_seq)[0]
    test_pssm['Func_alipathic']=get_func_group(test_seq)[1]
    test_pssm['Func_aromatic']=get_func_group(test_seq)[2]
    test_pssm['Func_negative']=get_func_group(test_seq)[3]
    test_pssm['Func_positive']=get_func_group(test_seq)[4]

    test_pssm['Volume_tiny']=get_volume(test_seq)[0]
    test_pssm['Volume_small']=get_volume(test_seq)[1]
    test_pssm['Volume_big']=get_volume(test_seq)[2]

    test_pssm['HBdonor']=get_h_bond(test_seq)[0]
    test_pssm['HBacceptor']=get_h_bond(test_seq)[1]
    return(test_pssm)
